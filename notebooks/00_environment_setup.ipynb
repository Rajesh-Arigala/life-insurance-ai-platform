# %%
import sys
import pandas as pd
import numpy as np
import sqlalchemy

print("Python:", sys.version)
print("Pandas:", pd.__version__)
print("NumPy:", np.__version__)
print("SQLAlchemy:", sqlalchemy.__version__)
# Out:
# Python: 3.11.16 (main, Aug 12 2026, 23:03:19) [Clang 17.0.0 (clang-1700.6.4.2)]
# Pandas: 3.0.5
# NumPy: 2.4.6
# SQLAlchemy: 2.0.52

# %%
df = pd.DataFrame({
    "policy_id": ["P001", "P002", "P003"],
    "premium": [25000, 18000, 42000]
})

df
# Out:
#   policy_id  premium
# 0      P001    25000
# 1      P002    18000
# 2      P003    42000

# %%
import sys
print(sys.executable)
print(sys.version)
# Out:
# /Users/jhonny001/Desktop/GenAi Notes/Implementations/life-insurance-ai-platform/.venv/bin/python
# 3.11.16 (main, Aug 12 2026, 23:03:19) [Clang 17.0.0 (clang-1700.6.4.2)]
